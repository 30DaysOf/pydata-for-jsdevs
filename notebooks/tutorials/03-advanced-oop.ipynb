# %% [markdown]
# > /createNotebook  advanced topics in OOP including classes, inheritance, methods and dunder

# %% [markdown]
# # Introduction to OOP
# Introduce OOP and its importance in programming. Explain how OOP helps in organizing and structuring code efficiently.

# %%
# Define a class called Person
class Person:
    # Define the __init__ method with name and age as parameters
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    # Define a method called say_hello
    def say_hello(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")
    
# Create an instance of the Person class
person1 = Person("John", 25)

# Call the say_hello method on the person1 instance
person1.say_hello()

# %% [markdown]
# # Classes
# Explain classes in Python, including creating classes, attributes, and methods. Show examples of using classes in Python programs.

# %%
# Define a class called Car
class Car:
    # Define the __init__ method with make, model, and year as parameters
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    # Define a method called start_engine
    def start_engine(self):
        print(f"The {self.make} {self.model} from {self.year} is starting its engine.")
    
# Create an instance of the Car class
car1 = Car("Toyota", "Camry", 2021)

# Call the start_engine method on the car1 instance
car1.start_engine()

# %% [markdown]
# # Inheritance
# Explain inheritance in Python, including creating subclasses and overriding methods. Show examples of using inheritance in Python programs.

# %%
# Define a subclass called Student that inherits from the Person class
class Student(Person):
    # Define the __init__ method with name, age, and major as parameters
    def __init__(self, name, age, major):
        # Call the __init__ method of the Person class and pass name and age as arguments
        super().__init__(name, age)
        self.major = major
    
    # Override the say_hello method of the Person class
    def say_hello(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old. My major is {self.major}.")
    
# Create an instance of the Student class
student1 = Student("Jane", 20, "Computer Science")

# Call the say_hello method on the student1 instance
student1.say_hello()

# %% [markdown]
# # Methods
# Explain methods in Python, including instance methods, class methods, and static methods. Show examples of using methods in Python programs.

# %%
# Define a class called Rectangle
class Rectangle:
    # Define the __init__ method with width and height as parameters
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    # Define an instance method called area that calculates the area of the rectangle
    def area(self):
        return self.width * self.height
    
    # Define a class method called create_square that creates a square with equal width and height
    @classmethod
    def create_square(cls, side_length):
        return cls(side_length, side_length)
    
    # Define a static method called is_square that checks if a rectangle is a square
    @staticmethod
    def is_square(rectangle):
        return rectangle.width == rectangle.height

# Create an instance of the Rectangle class
rectangle1 = Rectangle(5, 10)

# Call the area method on the rectangle1 instance
print(rectangle1.area())

# Create a square using the create_square class method
square1 = Rectangle.create_square(7)

# Call the area method on the square1 instance
print(square1.area())

# Check if rectangle1 is a square using the is_square static method
print(Rectangle.is_square(rectangle1))

# Check if square1 is a square using the is_square static method
print(Rectangle.is_square(square1))

# %% [markdown]
# # Dunder Methods
# Explain dunder methods in Python, including __init__, __str__, and __repr__. Show examples of using dunder methods in Python programs.
#
# > 🤖 | /explain what a dunder method is and how it got that name
#
# ```html
# GitHub Copilot: A dunder method is a special method in Python that has double underscores (also known as "dunder") at the beginning and end of its name. These methods are also called "magic methods" because they provide special functionality to classes in Python.
#
# Dunder methods are used to define how objects of a class behave in certain situations. For example, the `__init__` method is used to initialize an object when it is created, while the `__str__` method is used to define how an object is represented as a string.
#
# The name "dunder" comes from the fact that these methods have double underscores at the beginning and end of their names. "Dunder" is short for "double underscore". For example, `__init__` is pronounced "dunder init".
#
# Dunder methods are an important part of Python's object-oriented programming (OOP) model, and understanding how they work is essential for creating well-designed and efficient Python programs.
# ```

# %%
# Define a class called Person
class Person:
    # Define the __init__ method with name and age as parameters
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    # Define a method called say_hello
    def say_hello(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")
    
# Create an instance of the Person class
person1 = Person("John", 25)

# Call the say_hello method on the person1 instance
person1.say_hello()

# Define a class called Car
class Car:
    # Define the __init__ method with make, model, and year as parameters
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    
    # Define a method called start_engine
    def start_engine(self):
        print(f"The {self.make} {self.model} from {self.year} is starting its engine.")
    
# Create an instance of the Car class
car1 = Car("Toyota", "Camry", 2021)

# Call the start_engine method on the car1 instance
car1.start_engine()

# Define a subclass called Student that inherits from the Person class
class Student(Person):
    # Define the __init__ method with name, age, and major as parameters
    def __init__(self, name, age, major):
        # Call the __init__ method of the Person class and pass name and age as arguments
        super().__init__(name, age)
        self.major = major
    
    # Override the say_hello method of the Person class
    def say_hello(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old. My major is {self.major}.")
    
# Create an instance of the Student class
student1 = Student("Jane", 20, "Computer Science")

# Call the say_hello method on the student1 instance
student1.say_hello()

# Define a class called Rectangle
class Rectangle:
    # Define the __init__ method with width and height as parameters
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    # Define an instance method called area that calculates the area of the rectangle
    def area(self):
        return self.width * self.height
    
    # Define a class method called create_square that creates a square with equal width and height
    @classmethod
    def create_square(cls, side_length):
        return cls(side_length, side_length)
    
    # Define a static method called is_square that checks if a rectangle is a square
    @staticmethod
    def is_square(rectangle):
        return rectangle.width == rectangle.height

# Create an instance of the Rectangle class
rectangle1 = Rectangle(5, 10)

# Call the area method on the rectangle1 instance
print(rectangle1.area())

# Create a square using the create_square class method
square1 = Rectangle.create_square(7)

# Call the area method on the square1 instance
print(square1.area())

# Check if rectangle1 is a square using the is_square static method
print(Rectangle.is_square(rectangle1))

# Check if square1 is a square using the is_square static method
print(Rectangle.is_square(square1))

# Define a class called Book
class Book:
    # Define the __init__ method with title, author, and pages as parameters
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages
    
    # Define the __str__ method that returns a string representation of the book
    def __str__(self):
        return f"{self.title} by {self.author}, {self.pages} pages"
    
    # Define the __repr__ method that returns a string representation of the book
    def __repr__(self):
        return f"Book('{self.title}', '{self.author}', {self.pages})"

# Create an instance of the Book class
book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", 180)

# Print the string representation of the book using the __str__ method
print(book1)

# Print the string representation of the book using the __repr__ method
print(repr(book1))
