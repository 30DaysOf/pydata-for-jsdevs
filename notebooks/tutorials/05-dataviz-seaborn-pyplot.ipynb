# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including Pandas, Matplotlib, and Plotly.

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Load Data from CSV File
# Use Pandas to read the data from the CSV file into a DataFrame.

# %%
# Load data from CSV file into a Pandas DataFrame
df = pd.read_csv('./../../data/kaggle/TED-talks.csv')

# Print the first 5 rows of the DataFrame to check if the data was loaded correctly
#print(df.head())

# Show the output displayed as a table
from IPython.display import display
display(df.head())

# Display the dimensions of the data
print("Dimensions of the data:")
print(df.shape)

# Display column names and data types as a table
print("\nColumn names and data types:")
print(df.dtypes)
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2  https://ted.com/talks/martin_reeves_how_play_c...
# 3  https://ted.com/talks/james_k_thornton_why_is_...
# 4  https://ted.com/talks/mahendra_singhi_cement_s...
# Dimensions of the data:
# (5440, 6)
#
# Column names and data types:
# title     object
# author    object
# date      object
# views      int64
# likes      int64
# link      object
# dtype: object

# %% [markdown]
# # Most Viewed TED Talks

# %%
# Create a table with the top 20 most liked TED talks by 
# sorting the values for the likes column in descending order

top_20_liked_talks = df.nlargest(20, 'likes')
display(top_20_liked_talks)
# Out:
#                                                   title  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4605                         The power of vulnerability
# 4765                   How great leaders inspire action
# 3504         How to speak so that people want to listen
# 2168                     My philosophy for a happy life
# 3251                 The next outbreak? We're not ready
# 3017  What makes a good life? Lessons from the longe...
# 2166                 Why people believe they can't draw
# 3994  Looks aren't everything. Believe me, I'm a model.
# 4990             10 things you didn't know about orgasm
# 3799                          The orchestra in my mouth
# 4407                                 How to spot a liar
# 3758                            The art of misdirection
# 4280                            The power of introverts
# 4912                       The danger of a single story
# 4846                How I held my breath for 17 minutes
# 2170                 How to stop screwing yourself over
# 3769                     How to make stress your friend
#
#                         author            date     views    likes  \
# 5436          Sir Ken Robinson   February 2006  72000000  2100000
# 4084                 Amy Cuddy       June 2012  64000000  1900000
# 2958                 Tim Urban   February 2016  60000000  1800000
# 4605               Brené Brown       June 2010  56000000  1700000
# 4765               Simon Sinek  September 2009  57000000  1700000
# 3504           Julian Treasure       June 2013  49000000  1400000
# 2168                 Sam Berns    October 2013  43000000  1300000
# 3251                Bill Gates      March 2015  43000000  1300000
# 3017          Robert Waldinger   November 2015  41000000  1200000
# 2166               Graham Shaw   February 2015  37000000  1100000
# 3994           Cameron Russell    October 2012  38000000  1100000
# 4990                Mary Roach   February 2009  37000000  1100000
# 3799                  Tom Thum        May 2013  34000000  1000000
# 4407              Pamela Meyer       July 2011  31000000   953000
# 3758            Apollo Robbins       June 2013  31000000   933000
# 4280                Susan Cain   February 2012  30000000   915000
# 4912  Chimamanda Ngozi Adichie       July 2009  30000000   909000
# 4846              David Blaine    October 2009  28000000   857000
# 2170               Mel Robbins       June 2011  28000000   855000
# 3769           Kelly McGonigal       June 2013  28000000   855000
#
#                                                    link
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 4084  https://ted.com/talks/amy_cuddy_your_body_lang...
# 2958  https://ted.com/talks/tim_urban_inside_the_min...
# 4605  https://ted.com/talks/brene_brown_the_power_of...
# 4765  https://ted.com/talks/simon_sinek_how_great_le...
# 3504  https://ted.com/talks/julian_treasure_how_to_s...
# 2168  https://ted.com/talks/sam_berns_my_philosophy_...
# 3251  https://ted.com/talks/bill_gates_the_next_outb...
# 3017  https://ted.com/talks/robert_waldinger_what_ma...
# 2166  https://ted.com/talks/graham_shaw_why_people_b...
# 3994  https://ted.com/talks/cameron_russell_looks_ar...
# 4990  https://ted.com/talks/mary_roach_10_things_you...
# 3799  https://ted.com/talks/tom_thum_the_orchestra_i...
# 4407  https://ted.com/talks/pamela_meyer_how_to_spot...
# 3758  https://ted.com/talks/apollo_robbins_the_art_o...
# 4280  https://ted.com/talks/susan_cain_the_power_of_...
# 4912  https://ted.com/talks/chimamanda_ngozi_adichie...
# 4846  https://ted.com/talks/david_blaine_how_i_held_...
# 2170  https://ted.com/talks/mel_robbins_how_to_stop_...
# 3769  https://ted.com/talks/kelly_mcgonigal_how_to_m...

# %%
# For each 'author' column value, calculate total and average values by view and like columns
# Then create a table with the top 20 authors by total number of views 
#  Show the number of talks given with column name "Talks Given"
#  Show the total number of views with column name "Total Views"
#  Show the average number of views per talk with column name "Avg Views/Talk"
#  Show the average number of likes per talk with column name "Avg Likes/Talk"
#  Show the highest number of views for a single talk with column name "Highest Viewed"
# Show the highest number of likes for a single talk with column name "Highest Liked"

# group the data by author and calculate the required statistics
author_stats = df.groupby('author').agg({'views': ['count', 'sum', 'mean'], 'likes': ['mean', 'max']})

# flatten the multi-level column index
author_stats.columns = ['_'.join(col).strip() for col in author_stats.columns.values]

# sort the data by total views and select the top 20 authors
top_20_authors = author_stats.sort_values(by='views_sum', ascending=False).head(20)

# rename the columns as required
top_20_authors = top_20_authors.rename(columns={'views_count': 'Talks Given', 'views_sum': 'Total Views', 'views_mean': 'Avg Views/Talk', 'likes_mean': 'Avg Likes/Talk', 'likes_max': 'Highest Liked'})

# add a new column for highest viewed talk
top_20_authors['Highest Viewed'] = df.loc[df['views'].idxmax(), 'views']

# display the top 20 authors table
display(top_20_authors)
# Out:
#                           Talks Given  Total Views  Avg Views/Talk  \
# author
# Alex Gendler                       45    187196000    4.159911e+06
# Sir Ken Robinson                    5     95654000    1.913080e+07
# Bill Gates                          8     77800000    9.725000e+06
# Simon Sinek                         3     74800000    2.493333e+07
# Brené Brown                         2     72000000    3.600000e+07
# Julian Treasure                     5     64300000    1.286000e+07
# Amy Cuddy                           1     64000000    6.400000e+07
# Tim Urban                           1     60000000    6.000000e+07
# Iseult Gillespie                   33     54998000    1.666606e+06
# Mia Nacamulli                       5     44174000    8.834800e+06
# Sam Berns                           1     43000000    4.300000e+07
# Robert Waldinger                    1     41000000    4.100000e+07
# Esther Perel                        3     39400000    1.313333e+07
# Cameron Russell                     1     38000000    3.800000e+07
# Mary Roach                          1     37000000    3.700000e+07
# Graham Shaw                         1     37000000    3.700000e+07
# Hans Rosling                        9     36255000    4.028333e+06
# Elon Musk                           2     35800000    1.790000e+07
# Chimamanda Ngozi Adichie            2     34800000    1.740000e+07
# Tom Thum                            1     34000000    3.400000e+07
#
#                           Avg Likes/Talk  Highest Liked  Highest Viewed
# author
# Alex Gendler                1.264667e+05         723000        72000000
# Sir Ken Robinson            5.667200e+05        2100000        72000000
# Bill Gates                  2.936250e+05        1300000        72000000
# Simon Sinek                 7.486667e+05        1700000        72000000
# Brené Brown                 1.102000e+06        1700000        72000000
# Julian Treasure             3.740000e+05        1400000        72000000
# Amy Cuddy                   1.900000e+06        1900000        72000000
# Tim Urban                   1.800000e+06        1800000        72000000
# Iseult Gillespie            5.033030e+04         200000        72000000
# Mia Nacamulli               2.790000e+05         533000        72000000
# Sam Berns                   1.300000e+06        1300000        72000000
# Robert Waldinger            1.200000e+06        1200000        72000000
# Esther Perel                3.986667e+05         577000        72000000
# Cameron Russell             1.100000e+06        1100000        72000000
# Mary Roach                  1.100000e+06        1100000        72000000
# Graham Shaw                 1.100000e+06        1100000        72000000
# Hans Rosling                1.224444e+05         458000        72000000
# Elon Musk                   5.425000e+05         849000        72000000
# Chimamanda Ngozi Adichie    5.275000e+05         909000        72000000
# Tom Thum                    1.000000e+06        1000000        72000000

# %%
# For each 'author' column value, calculate total and average values by view and like columns
# Then create a table with the top 20 authors by average number of views per talk
#  Show the number of talks given with column name "Talks Given"
#  Show the total number of views with column name "Total Views"
#  Show the average number of views per talk with column name "Avg Views/Talk"
#  Show the average number of likes per talk with column name "Avg Likes/Talk"
#  Show the highest number of views for a single talk with column name "Highest Viewed"
# Show the highest number of likes for a single talk with column name "Highest Liked"

# group the data by author and calculate the required statistics
author_stats = df.groupby('author').agg({'views': ['count', 'sum', 'mean'], 'likes': ['mean', 'max']})

# flatten the multi-level column index
author_stats.columns = ['_'.join(col).strip() for col in author_stats.columns.values]

# calculate the average views per talk
author_stats['Avg Views/Talk'] = author_stats['views_sum'] / author_stats['views_count']

# sort the data by average views per talk and select the top 20 authors
top_20_authors = author_stats.sort_values(by='Avg Views/Talk', ascending=False).head(20)

# rename the columns as required
top_20_authors = top_20_authors.rename(columns={'views_count': 'Talks Given', 'views_sum': 'Total Views', 'likes_mean': 'Avg Likes/Talk', 'views_mean': 'Avg Views/Talk', 'likes_max': 'Highest Liked'})

# add a new column for highest viewed talk
top_20_authors['Highest Viewed'] = df.loc[df['views'].idxmax(), 'views']

# display the top 20 authors table
display(top_20_authors)
# Out:
#                       Talks Given  Total Views  Avg Views/Talk  \
# author
# Amy Cuddy                       1     64000000      64000000.0
# Tim Urban                       1     60000000      60000000.0
# Sam Berns                       1     43000000      43000000.0
# Robert Waldinger                1     41000000      41000000.0
# Cameron Russell                 1     38000000      38000000.0
# Graham Shaw                     1     37000000      37000000.0
# Mary Roach                      1     37000000      37000000.0
# Brené Brown                     2     72000000      36000000.0
# Tom Thum                        1     34000000      34000000.0
# Pamela Meyer                    1     31000000      31000000.0
# Apollo Robbins                  1     31000000      31000000.0
# Susan Cain                      1     30000000      30000000.0
# Mel Robbins                     1     28000000      28000000.0
# Jill Bolte Taylor               1     28000000      28000000.0
# Dan Pink                        1     28000000      28000000.0
# Kelly McGonigal                 1     28000000      28000000.0
# David Blaine                    1     28000000      28000000.0
# Chris Anderson (TED)            1     26000000      26000000.0
# Celeste Headlee                 1     26000000      26000000.0
# Angela Lee Duckworth            1     25000000      25000000.0
#
#                       Avg Likes/Talk  Highest Liked  Avg Views/Talk  \
# author
# Amy Cuddy                  1900000.0        1900000      64000000.0
# Tim Urban                  1800000.0        1800000      60000000.0
# Sam Berns                  1300000.0        1300000      43000000.0
# Robert Waldinger           1200000.0        1200000      41000000.0
# Cameron Russell            1100000.0        1100000      38000000.0
# Graham Shaw                1100000.0        1100000      37000000.0
# Mary Roach                 1100000.0        1100000      37000000.0
# Brené Brown                1102000.0        1700000      36000000.0
# Tom Thum                   1000000.0        1000000      34000000.0
# Pamela Meyer                953000.0         953000      31000000.0
# Apollo Robbins              933000.0         933000      31000000.0
# Susan Cain                  915000.0         915000      30000000.0
# Mel Robbins                 855000.0         855000      28000000.0
# Jill Bolte Taylor           844000.0         844000      28000000.0
# Dan Pink                    843000.0         843000      28000000.0
# Kelly McGonigal             855000.0         855000      28000000.0
# David Blaine                857000.0         857000      28000000.0
# Chris Anderson (TED)        782000.0         782000      26000000.0
# Celeste Headlee             789000.0         789000      26000000.0
# Angela Lee Duckworth        773000.0         773000      25000000.0
#
#                       Highest Viewed
# author
# Amy Cuddy                   72000000
# Tim Urban                   72000000
# Sam Berns                   72000000
# Robert Waldinger            72000000
# Cameron Russell             72000000
# Graham Shaw                 72000000
# Mary Roach                  72000000
# Brené Brown                 72000000
# Tom Thum                    72000000
# Pamela Meyer                72000000
# Apollo Robbins              72000000
# Susan Cain                  72000000
# Mel Robbins                 72000000
# Jill Bolte Taylor           72000000
# Dan Pink                    72000000
# Kelly McGonigal             72000000
# David Blaine                72000000
# Chris Anderson (TED)        72000000
# Celeste Headlee             72000000
# Angela Lee Duckworth        72000000

# %%
# Identify the top 20 authors who had the most total views across all their talks
# Visualize the data in a stacked bar chart with the author name on the x-axis and the total views on the y-axis
# Use a color palette of your choice
# For each bar, show the stacked values for each talk given by that author that contributes to the total views

# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from CSV file into a Pandas DataFrame
df = pd.read_csv('./../../data/kaggle/TED-talks.csv')

# group the data by author and calculate the total views
author_views = df.groupby('author')['views'].sum()

# sort the data by total views and select the top 20 authors
top_20_authors = author_views.sort_values(ascending=False).head(20)

# get the data for the top 20 authors
top_20_data = df[df['author'].isin(top_20_authors.index)]

# group the data by author and talk and calculate the views for each talk
talk_views = top_20_data.groupby(['author', 'title'])['views'].sum()

# unstack the data to create a stacked bar chart
talk_views.unstack().plot(kind='bar', stacked=True, figsize=(15, 10))

# set the title and axis labels
plt.title('Top 20 Authors by Total Views')
plt.xlabel('Author')
plt.ylabel('Total Views')

# show the plot
plt.show()

# %%
#Create a table with the top 20 authors based on their total views across all their talk_views
#Show the table sorted by the total views in descending order
# For each row show the author, total number of talks given, total views across talks, highest view, lowest view and average view

# group the data by author and calculate the required statistics
author_stats = df.groupby('author').agg({'views': ['count', 'sum', 'max', 'min', 'mean']})

# flatten the multi-level column index
author_stats.columns = ['_'.join(col).strip() for col in author_stats.columns.values]

# sort the data by total views and select the top 20 authors
top_20_authors = author_stats.sort_values(by='views_sum', ascending=False).head(20)

# rename the columns as required
top_20_authors = top_20_authors.rename(columns={'views_count': 'Total Talks Given', 'views_sum': 'Total Views', 'views_max': 'Highest View', 'views_min': 'Lowest View', 'views_mean': 'Average View'})

# display the top 20 authors table
display(top_20_authors)
# Out:
#                           Total Talks Given  Total Views  Highest View  \
# author
# Alex Gendler                             45    187196000      24000000
# Sir Ken Robinson                          5     95654000      72000000
# Bill Gates                                8     77800000      43000000
# Simon Sinek                               3     74800000      57000000
# Brené Brown                               2     72000000      56000000
# Julian Treasure                           5     64300000      49000000
# Amy Cuddy                                 1     64000000      64000000
# Tim Urban                                 1     60000000      60000000
# Iseult Gillespie                         33     54998000       6600000
# Mia Nacamulli                             5     44174000      17000000
# Sam Berns                                 1     43000000      43000000
# Robert Waldinger                          1     41000000      41000000
# Esther Perel                              3     39400000      19000000
# Cameron Russell                           1     38000000      38000000
# Mary Roach                                1     37000000      37000000
# Graham Shaw                               1     37000000      37000000
# Hans Rosling                              9     36255000      15000000
# Elon Musk                                 2     35800000      28000000
# Chimamanda Ngozi Adichie                  2     34800000      30000000
# Tom Thum                                  1     34000000      34000000
#
#                           Lowest View  Average View
# author
# Alex Gendler                   422000  4.159911e+06
# Sir Ken Robinson               254000  1.913080e+07
# Bill Gates                    1700000  9.725000e+06
# Simon Sinek                   1800000  2.493333e+07
# Brené Brown                  16000000  3.600000e+07
# Julian Treasure               1300000  1.286000e+07
# Amy Cuddy                    64000000  6.400000e+07
# Tim Urban                    60000000  6.000000e+07
# Iseult Gillespie               332000  1.666606e+06
# Mia Nacamulli                  974000  8.834800e+06
# Sam Berns                    43000000  4.300000e+07
# Robert Waldinger             41000000  4.100000e+07
# Esther Perel                  1400000  1.313333e+07
# Cameron Russell              38000000  3.800000e+07
# Mary Roach                   37000000  3.700000e+07
# Graham Shaw                  37000000  3.700000e+07
# Hans Rosling                   955000  4.028333e+06
# Elon Musk                     7800000  1.790000e+07
# Chimamanda Ngozi Adichie      4800000  1.740000e+07
# Tom Thum                     34000000  3.400000e+07

# %%
# Identify the top 20 authors who had the most total views across all their talks
# Visualize the data in a stacked bar chart with the author name on the x-axis and the total views on the y-axis
# Write the x-axis labels vertically - for each author show their name and the total number of talks given
# Use a color palette of your choice
# For each bar, show the stacked values for each talk given by that author that contributes to the total views
# Hide the legend
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load data from CSV file into a Pandas DataFrame
df = pd.read_csv('./../../data/kaggle/TED-talks.csv')

# group the data by author and calculate the total views
author_views = df.groupby('author')['views'].sum()

# sort the data by total views and select the top 20 authors
top_20_authors = author_views.sort_values(ascending=False).head(20)

# get the data for the top 20 authors
top_20_data = df[df['author'].isin(top_20_authors.index)]

# group the data by author and talk and calculate the views for each talk
talk_views = top_20_data.groupby(['author', 'title'])['views'].sum()

# unstack the data to create a stacked bar chart
ax = talk_views.unstack().plot(kind='bar', stacked=True, figsize=(15, 10))

# set the title and axis labels
plt.title('Top 20 Authors by Total Views')
plt.xlabel('Author')
plt.ylabel('Total Views')

# write the x-axis labels vertically
plt.xticks(rotation=90)

# write the x-axis labels vertically - for each author show their name and the total number of talks given
labels = []
for author in top_20_authors.index:
    talks_given = df[df['author'] == author]['title'].nunique()
    label = f'{author} - {talks_given}'
    labels.append(label)
ax.set_xticklabels(labels)

# Use a color palette of your choice
sns.set_palette('husl')

# Hide the legend
ax.legend().set_visible(False)

# show the plot
plt.show()
